# %% [markdown]
# # API 요청

# %% [markdown]
# > 경상남도에 있는 도서관 현황 정보를 파악하기 위해 해당 API를 요청하였습니다.
# https://www.data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15062509#/API%20%EB%AA%A9%EB%A1%9D/gyeongnalibraryList

# %%
import requests
from pprint import pprint

# %%
url = 'http://apis.data.go.kr/6480000/gyeongnamlibrarysituation/gyeongnalibraryList'
params = {
    'serviceKey' : '', 
    'numOfRows' : '1000', # 페이지 당 결과 수
    'pageNo' : '1', # 페이지 번호
    'resultType' : 'json' # 타입
    }

response = requests.get(url, params=params)

data = response.json()
pprint(data)
# Out:
# {'gyeongnalibraryList': {'body': {'items': {'item': [{'closedDays': '매주금요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-254-4819',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://lib.gyeongnam.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경남대표도서관',
#                                                       'openingYear': '2018',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '의창구 '
#                                                                      '사림로45번길 '
#                                                                      '59 (사림동)',
#                                                       'seq': '1',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-254-4811',
#                                                       'zipCode': '51138'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-240-4568',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://mslib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '마산도서관',
#                                                       'openingYear': '1954',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '마산합포구 '
#                                                                      '용마산길 12',
#                                                       'seq': '2',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-240-4521',
#                                                       'zipCode': '51334'},
#                                                      {'closedDays': '매월넷째주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-252-3865',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://jhlib.gne.go.kr/',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '마산지혜의바다도서관',
#                                                       'openingYear': '2018',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '마산회원구 '
#                                                                      '구암북12길 '
#                                                                      '24-1',
#                                                       'seq': '3',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-252-3860',
#                                                       'zipCode': '51203'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-271-0351',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://jdlib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '진동도서관',
#                                                       'openingYear': '1993',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '마산합포구 '
#                                                                      '진동면 '
#                                                                      '삼진의거대로 '
#                                                                      '661-94',
#                                                       'seq': '4',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-271-8145',
#                                                       'zipCode': '51793'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-278-2835',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://cwlib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '창원도서관',
#                                                       'openingYear': '1983',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '성산구 두대로 '
#                                                                      '203',
#                                                       'seq': '5',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-278-2831',
#                                                       'zipCode': '51519'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-225-4799',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.changwon.go.kr/gh/index_real.php',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '고향의봄도서관',
#                                                       'openingYear': '2002',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '의창구 '
#                                                                      '평산로135번길 '
#                                                                      '32 (서상동)',
#                                                       'seq': '6',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-225-7371',
#                                                       'zipCode': '51371'},
#                                                      {'closedDays': '매주금요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-225-4804',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.changwon.go.kr/ns/index_real.php',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '내서도서관',
#                                                       'openingYear': '1997',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '마산회원구 '
#                                                                      '내서읍 삼풍로 '
#                                                                      '79',
#                                                       'seq': '7',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-225-7491',
#                                                       'zipCode': '51224'},
#                                                      {'closedDays': '매주금요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-225-4806',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.changwon.go.kr/db/index_real.php',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '동부도서관',
#                                                       'openingYear': '2006',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '진해구 용재로 '
#                                                                      '66 (용원동)',
#                                                       'seq': '8',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-225-7531',
#                                                       'zipCode': '51604'},
#                                                      {'closedDays': '매주금요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-225-4803',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.changwon.go.kr/hp/index_real.php',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '마산합포도서관',
#                                                       'openingYear': '2002',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '마산합포구 '
#                                                                      '월영동16길 '
#                                                                      '22 (해운동)',
#                                                       'seq': '9',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-225-7441',
#                                                       'zipCode': '51742'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-225-4804',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.changwon.go.kr/hw/',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '마산회원도서관',
#                                                       'openingYear': '1995',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '마산회원구 '
#                                                                      '3·15대로 '
#                                                                      '558 '
#                                                                      '(회원동)',
#                                                       'seq': '10',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-225-7471',
#                                                       'zipCode': '51324'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-225-4799',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.changwon.go.kr/mg/index_real.php',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '명곡도서관',
#                                                       'openingYear': '2012',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '의창구 서곡길 '
#                                                                      '21 (명서동)',
#                                                       'seq': '11',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-225-7321',
#                                                       'zipCode': '51171'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-225-4801',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.changwon.go.kr/sn/index_real.php',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '상남도서관',
#                                                       'openingYear': '2002',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '성산구 원이대로 '
#                                                                      '810 '
#                                                                      '(가음정동)',
#                                                       'seq': '12',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-225-7411',
#                                                       'zipCode': '51500'},
#                                                      {'closedDays': '매주금요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-225-4801',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.changwon.go.kr/ss',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '성산도서관',
#                                                       'openingYear': '2010',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '성산구 외리로 '
#                                                                      '47 (남산동)',
#                                                       'seq': '13',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-225-7401',
#                                                       'zipCode': '51472'},
#                                                      {'closedDays': '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-225-4804',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.changwon.go.kr/jr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '중리초등복합시설도서관',
#                                                       'openingYear': '2014',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '마산회원구 '
#                                                                      '내서읍 호계안길 '
#                                                                      '22',
#                                                       'seq': '14',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-225-7492',
#                                                       'zipCode': '51215'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-225-4806',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.changwon.go.kr/jh',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '진해도서관',
#                                                       'openingYear': '1975',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '진해구 충장로 '
#                                                                      '141 '
#                                                                      '(여좌동)',
#                                                       'seq': '15',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-225-7511',
#                                                       'zipCode': '51694'},
#                                                      {'closedDays': '매주금요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-225-4799',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.changwon.go.kr/uc/index_real.php',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '창원중앙도서관',
#                                                       'openingYear': '1993',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '성산구 용호로 '
#                                                                      '50 (반송동)',
#                                                       'seq': '16',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-225-7331',
#                                                       'zipCode': '51434'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-547-0955',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://www.jhml.or.kr',
#                                                       'libraryClassification': '공공도서관(어린이)',
#                                                       'libraryNm': '진해기적의도서관',
#                                                       'openingYear': '2004',
#                                                       'roadaddress': '경상남도 창원시 '
#                                                                      '진해구 석동로 '
#                                                                      '70 (석동)',
#                                                       'seq': '17',
#                                                       'signguNm': '창원시',
#                                                       'tel': '055-547-0095',
#                                                       'zipCode': '51595'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-761-9606',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://jinlib.gne.go.kr/',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '진양도서관',
#                                                       'openingYear': '1992',
#                                                       'roadaddress': '경상남도 진주시 '
#                                                                      '문산읍 '
#                                                                      '동부로588번길 '
#                                                                      '24',
#                                                       'seq': '19',
#                                                       'signguNm': '진주시',
#                                                       'tel': '055-761-2722',
#                                                       'zipCode': '52834'},
#                                                      {'closedDays': '매월첫째주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-749-5988',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.jinju.go.kr/front/',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '진주시립서부도서관',
#                                                       'openingYear': '1998',
#                                                       'roadaddress': '경상남도 진주시 '
#                                                                      '평거로 249 '
#                                                                      '(이현동)',
#                                                       'seq': '20',
#                                                       'signguNm': '진주시',
#                                                       'tel': '055-749-5983',
#                                                       'zipCode': '52669'},
#                                                      {'closedDays': '매월첫째주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-749-5989',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://lib.jinju.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '진주시립연암도서관',
#                                                       'openingYear': '1985',
#                                                       'roadaddress': '경상남도 진주시 '
#                                                                      '모덕로47번길 '
#                                                                      '13-17 '
#                                                                      '(상대동)',
#                                                       'seq': '21',
#                                                       'signguNm': '진주시',
#                                                       'tel': '055-749-5982',
#                                                       'zipCode': '52786'},
#                                                      {'closedDays': '매월첫째주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-749-2898',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://lib.jinju.go.kr/front/',
#                                                       'libraryClassification': '공공도서관(어린이)',
#                                                       'libraryNm': '도동어린이도서관',
#                                                       'openingYear': '2009',
#                                                       'roadaddress': '경상남도 진주시 '
#                                                                      '상대로119번길 '
#                                                                      '17',
#                                                       'seq': '22',
#                                                       'signguNm': '진주시',
#                                                       'tel': '055-749-7496',
#                                                       'zipCode': '52780'},
#                                                      {'closedDays': '매주일~월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-761-1141',
#                                                       'founder': '사립',
#                                                       'homepage': 'http://www.mahacl.com/',
#                                                       'libraryClassification': '공공도서관(어린이)',
#                                                       'libraryNm': '마하 어린이도서관',
#                                                       'openingYear': '2018',
#                                                       'roadaddress': '경상남도 진주시 '
#                                                                      '초장로 55 '
#                                                                      '(초전동)',
#                                                       'seq': '23',
#                                                       'signguNm': '진주시',
#                                                       'tel': '055-753-9922',
#                                                       'zipCode': '52737'},
#                                                      {'closedDays': '매월첫째주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-749-2894',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://lib.jinju.go.kr',
#                                                       'libraryClassification': '공공도서관(어린이)',
#                                                       'libraryNm': '비봉어린이도서관',
#                                                       'openingYear': '2009',
#                                                       'roadaddress': '경상남도 진주시 '
#                                                                      '향교로 86 '
#                                                                      '(옥봉동)',
#                                                       'seq': '24',
#                                                       'signguNm': '진주시',
#                                                       'tel': '055-749-7494',
#                                                       'zipCode': '52752'},
#                                                      {'closedDays': '매월첫째주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-749-5987',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://lib.jinju.go.kr',
#                                                       'libraryClassification': '공공도서관(어린이)',
#                                                       'libraryNm': '진주시어린이전문도서관',
#                                                       'openingYear': '2006',
#                                                       'roadaddress': '경상남도 진주시 '
#                                                                      '평거로 46',
#                                                       'seq': '25',
#                                                       'signguNm': '진주시',
#                                                       'tel': '055-749-5984',
#                                                       'zipCode': '52699'},
#                                                      {'closedDays': '매월첫째주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '000-000-0000',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://lib.jinju.go.kr',
#                                                       'libraryClassification': '공공도서관(어린이)',
#                                                       'libraryNm': '진주시혁신어린이도서관',
#                                                       'openingYear': '2020',
#                                                       'roadaddress': '경상남도 진주시 '
#                                                                      '동진로 415 '
#                                                                      '(충무공동)',
#                                                       'seq': '26',
#                                                       'signguNm': '진주시',
#                                                       'tel': '055-749-7490',
#                                                       'zipCode': '52830'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-648-1608',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://tylib.gne.go.kr/',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '통영도서관',
#                                                       'openingYear': '1963',
#                                                       'roadaddress': '경상남도 통영시 '
#                                                                      '봉수로 37',
#                                                       'seq': '27',
#                                                       'signguNm': '통영시',
#                                                       'tel': '055-648-8093',
#                                                       'zipCode': '53077'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-650-2639',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://www.tongyeonglib.or.kr/library/',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '통영시립도서관',
#                                                       'openingYear': '2010',
#                                                       'roadaddress': '경상남도 통영시 '
#                                                                      '무전3길 29 '
#                                                                      '(무전동)',
#                                                       'seq': '28',
#                                                       'signguNm': '통영시',
#                                                       'tel': '055-650-2630',
#                                                       'zipCode': '53035'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-650-2509',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://www.tongyeonglib.or.kr/library/',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '꿈이랑도서관',
#                                                       'openingYear': '1997',
#                                                       'roadaddress': '경상남도 통영시 '
#                                                                      '산양읍 둔전길 '
#                                                                      '155',
#                                                       'seq': '29',
#                                                       'signguNm': '통영시',
#                                                       'tel': '055-650-2500',
#                                                       'zipCode': '53084'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-650-2639',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://www.tongyeonglib.or.kr/library/',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '통영시립욕지도서관',
#                                                       'openingYear': '2001',
#                                                       'roadaddress': '경상남도 통영시 '
#                                                                      '중촌길 203',
#                                                       'seq': '30',
#                                                       'signguNm': '통영시',
#                                                       'tel': '055-650-4580',
#                                                       'zipCode': '53100'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-650-2649',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://www.tongyeonglib.or.kr/',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '통영시립충무도서관',
#                                                       'openingYear': '2013',
#                                                       'roadaddress': '경상남도 통영시 '
#                                                                      '용남면 '
#                                                                      '기호바깥길 '
#                                                                      '7-87',
#                                                       'seq': '31',
#                                                       'signguNm': '통영시',
#                                                       'tel': '055-650-2640',
#                                                       'zipCode': '53017'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-855-7740',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://salib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '사천도서관',
#                                                       'openingYear': '1991',
#                                                       'roadaddress': '경상남도 사천시 '
#                                                                      '사천읍 평화2길 '
#                                                                      '21',
#                                                       'seq': '32',
#                                                       'signguNm': '사천시',
#                                                       'tel': '055-853-8406',
#                                                       'zipCode': '52518'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-834-8928',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://scplib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '삼천포도서관',
#                                                       'openingYear': '1990',
#                                                       'roadaddress': '경상남도 사천시 '
#                                                                      '삼천포대교로 '
#                                                                      '622',
#                                                       'seq': '33',
#                                                       'signguNm': '사천시',
#                                                       'tel': '055-835-4436',
#                                                       'zipCode': '52553'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-831-2969',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://elc.sacheon.go.kr/',
#                                                       'libraryClassification': '공공도서관(어린이)',
#                                                       'libraryNm': '사천시어린이도서관',
#                                                       'openingYear': '2011',
#                                                       'roadaddress': '경상남도 사천시 '
#                                                                      '사남면 조동길 '
#                                                                      '49-30',
#                                                       'seq': '34',
#                                                       'signguNm': '사천시',
#                                                       'tel': '055-831-2966',
#                                                       'zipCode': '52533'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-320-5574',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://ghlib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '김해도서관',
#                                                       'openingYear': '1985',
#                                                       'roadaddress': '경상남도 김해시 '
#                                                                      '가락로 93번길 '
#                                                                      '72',
#                                                       'seq': '35',
#                                                       'signguNm': '김해시',
#                                                       'tel': '055-320-5564',
#                                                       'zipCode': '50918'},
#                                                      {'closedDays': '매월둘째주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-330-9830',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://ghjhlib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '김해지혜의바다도서관',
#                                                       'openingYear': '2019',
#                                                       'roadaddress': '경상남도 김해시 '
#                                                                      '주촌면 '
#                                                                      '서부로1541번길 '
#                                                                      '8',
#                                                       'seq': '36',
#                                                       'signguNm': '김해시',
#                                                       'tel': '055-330-9800',
#                                                       'zipCode': '50877'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-343-8798',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://jylib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '진영도서관',
#                                                       'openingYear': '1990',
#                                                       'roadaddress': '경상남도 김해시 '
#                                                                      '진영읍 진영로 '
#                                                                      '265번길 '
#                                                                      '9-61',
#                                                       'seq': '37',
#                                                       'signguNm': '김해시',
#                                                       'tel': '055-343-8792',
#                                                       'zipCode': '50864'},
#                                                      {'closedDays': '매월마지막주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-336-9400',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://lib.gimhae.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '김해율하도서관',
#                                                       'openingYear': '2018',
#                                                       'roadaddress': '경상남도 김해시 '
#                                                                      '율하2로 210 '
# ...
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://ysl.cng.go.kr/main/',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '창녕군 영산도서관',
#                                                       'openingYear': '2014',
#                                                       'roadaddress': '경상남도 창녕군 '
#                                                                      '영산면 원다리길 '
#                                                                      '34',
#                                                       'seq': '67',
#                                                       'signguNm': '창녕군',
#                                                       'tel': '055-530-1931',
#                                                       'zipCode': '50348'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-673-8464',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://gslib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '고성도서관',
#                                                       'openingYear': '1990',
#                                                       'roadaddress': '경상남도 고성군 '
#                                                                      '고성읍 '
#                                                                      '동외로195번길 '
#                                                                      '6',
#                                                       'seq': '68',
#                                                       'signguNm': '고성군',
#                                                       'tel': '055-673-8437',
#                                                       'zipCode': '52937'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-670-2917',
#                                                       'founder': '지자체',
#                                                       'homepage': 'https://www.goseong.go.kr/gslib/index.goseong',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '고성동부도서관',
#                                                       'openingYear': '2003',
#                                                       'roadaddress': '경상남도 고성군 '
#                                                                      '회화면 '
#                                                                      '관인로44번길 '
#                                                                      '26-5',
#                                                       'seq': '69',
#                                                       'signguNm': '고성군',
#                                                       'tel': '055-670-2916',
#                                                       'zipCode': '52943'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-864-2074',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://nhlib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '남해도서관',
#                                                       'openingYear': '1972',
#                                                       'roadaddress': '경상남도 남해군 '
#                                                                      '남해읍 '
#                                                                      '화전로43번길 '
#                                                                      '11-3',
#                                                       'seq': '70',
#                                                       'signguNm': '남해군',
#                                                       'tel': '055-864-0973',
#                                                       'zipCode': '52427'},
#                                                      {'closedDays': '매주화요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-860-3879',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://lib.namhae.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '화전도서관',
#                                                       'openingYear': '2009',
#                                                       'roadaddress': '경상남도 남해군 '
#                                                                      '망운로30번길 '
#                                                                      '9',
#                                                       'seq': '71',
#                                                       'signguNm': '남해군',
#                                                       'tel': '055-860-3864',
#                                                       'zipCode': '52419'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-882-5958',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://hdlib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '하동도서관',
#                                                       'openingYear': '1985',
#                                                       'roadaddress': '경상남도 하동군 '
#                                                                      '하동읍 경서대로 '
#                                                                      '80',
#                                                       'seq': '72',
#                                                       'signguNm': '하동군',
#                                                       'tel': '055-884-7981',
#                                                       'zipCode': '52332'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-973-2711',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://sanlib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '산청도서관',
#                                                       'openingYear': '1984',
#                                                       'roadaddress': '경상남도 산청군 '
#                                                                      '산청읍 '
#                                                                      '꽃봉산로79번길 '
#                                                                      '45',
#                                                       'seq': '73',
#                                                       'signguNm': '산청군',
#                                                       'tel': '055-973-2547',
#                                                       'zipCode': '52220'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-974-1622',
#                                                       'founder': '교육청',
#                                                       'homepage': 'https://sjlib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '산청지리산도서관',
#                                                       'openingYear': '2020',
#                                                       'roadaddress': '경상남도 산청군 '
#                                                                      '신안면 '
#                                                                      '원지강변로 '
#                                                                      '101',
#                                                       'seq': '74',
#                                                       'signguNm': '산청군',
#                                                       'tel': '055-974-1611',
#                                                       'zipCode': '52249'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-964-0810',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://hylib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '함양도서관',
#                                                       'openingYear': '1963',
#                                                       'roadaddress': '경상남도 함양군 '
#                                                                      '함양읍 함양로 '
#                                                                      '1143-1',
#                                                       'seq': '75',
#                                                       'signguNm': '함양군',
#                                                       'tel': '055-963-3186',
#                                                       'zipCode': '50036'},
#                                                      {'closedDays': '매주금요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-940-8499',
#                                                       'founder': '지자체',
#                                                       'homepage': 'http://library.geochang.go.kr/',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '거창군립한마음도서관',
#                                                       'openingYear': '2006',
#                                                       'roadaddress': '경상남도 거창군 '
#                                                                      '거창읍 '
#                                                                      '거열로6길 11',
#                                                       'seq': '76',
#                                                       'signguNm': '거창군',
#                                                       'tel': '055-940-8470',
#                                                       'zipCode': '50130'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-943-6052',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://gclib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '거창도서관',
#                                                       'openingYear': '1984',
#                                                       'roadaddress': '경상남도 거창군 '
#                                                                      '거창읍 하동1길 '
#                                                                      '9',
#                                                       'seq': '77',
#                                                       'signguNm': '거창군',
#                                                       'tel': '055-944-8594',
#                                                       'zipCode': '50133'},
#                                                      {'closedDays': '매주월요일, '
#                                                                     '법정공휴일',
#                                                       'ctprvnNm': '경상남도',
#                                                       'fax': '055-932-3945',
#                                                       'founder': '교육청',
#                                                       'homepage': 'http://hclib.gne.go.kr',
#                                                       'libraryClassification': '공공도서관(일반)',
#                                                       'libraryNm': '경상남도교육청 '
#                                                                    '합천도서관',
#                                                       'openingYear': '1972',
#                                                       'roadaddress': '경상남도 합천군 '
#                                                                      '합천읍 동서로 '
#                                                                      '152',
#                                                       'seq': '78',
#                                                       'signguNm': '합천군',
#                                                       'tel': '055-932-0936',
#                                                       'zipCode': '50238'}]},
#                                   'numOfRows': 1000,
#                                   'pageNo': 1,
#                                   'totalCount': 76},
#                          'header': {'resultCode': '00',
#                                     'resultMsg': 'NORMAL_CODE'}}}

# %% [markdown]
# # DataFrame 생성

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(data['gyeongnalibraryList']['body']['items']['item'])
print(df.shape)
df.head()
# Out:
# (76, 13)
#   seq ctprvnNm signguNm           libraryNm zipCode  \
# 0   1     경상남도      창원시             경남대표도서관   51138
# 1   2     경상남도      창원시       경상남도교육청 마산도서관   51334
# 2   3     경상남도      창원시  경상남도교육청 마산지혜의바다도서관   51203
# 3   4     경상남도      창원시       경상남도교육청 진동도서관   51793
# 4   5     경상남도      창원시       경상남도교육청 창원도서관   51519
#
#                         roadaddress                    homepage           tel  \
# 0     경상남도 창원시 의창구 사림로45번길 59 (사림동)  http://lib.gyeongnam.go.kr  055-254-4811
# 1            경상남도 창원시 마산합포구 용마산길 12      http://mslib.gne.go.kr  055-240-4521
# 2        경상남도 창원시 마산회원구 구암북12길 24-1     http://jhlib.gne.go.kr/  055-252-3860
# 3  경상남도 창원시 마산합포구 진동면 삼진의거대로 661-94      http://jdlib.gne.go.kr  055-271-8145
# 4              경상남도 창원시 성산구 두대로 203      http://cwlib.gne.go.kr  055-278-2831
#
#         closedDays openingYear libraryClassification founder           fax
# 0     매주금요일, 법정공휴일        2018             공공도서관(일반)     지자체  055-254-4819
# 1     매주월요일, 법정공휴일        1954             공공도서관(일반)     교육청  055-240-4568
# 2  매월넷째주월요일, 법정공휴일        2018             공공도서관(일반)     교육청  055-252-3865
# 3     매주월요일, 법정공휴일        1993             공공도서관(일반)     교육청  055-271-0351
# 4     매주월요일, 법정공휴일        1983             공공도서관(일반)     교육청  055-278-2835

# %% [markdown]
# # 분석

# %% [markdown]
# ## 지역별 도서관 수

# %%
df1 = df['signguNm'].value_counts().to_frame().reset_index()
df1
# Out:
#    signguNm  count
# 0       창원시     17
# 1       김해시      9
# 2       진주시      8
# 3       거제시      7
# 4       양산시      6
# 5       통영시      5
# 6       밀양시      4
# 7       사천시      3
# 8       창녕군      3
# 9       남해군      2
# 10      거창군      2
# 11      산청군      2
# 12      함안군      2
# 13      고성군      2
# 14      하동군      1
# 15      함양군      1
# 16      의령군      1
# 17      합천군      1

# %% [markdown]
# ## 도서관이 가장 많은 지역

# %%
df1.iloc[[0]]
# Out:
#   signguNm  count
# 0      창원시     17

# %% [markdown]
# ## 도서관이 가장 적은 지역

# %%
df1.iloc[[-1]]
# Out:
#    signguNm  count
# 17      합천군      1

# %% [markdown]
# ## 가장 최근에 개관한 도서관

# %%
df['openingYear'] = df['openingYear'].astype("int")

# %%
df.loc[df['openingYear'] == np.max(df['openingYear'])][['ctprvnNm', 'signguNm', 'libraryNm', 'openingYear']]
# Out:
#    ctprvnNm signguNm  libraryNm  openingYear
# 47     경상남도      거제시  거제시립아주도서관         2021

# %% [markdown]
# ## 가장 오래된 도서관

# %%
df.loc[df['openingYear'] == np.min(df['openingYear'])][['ctprvnNm', 'signguNm', 'libraryNm', 'openingYear']]
# Out:
#   ctprvnNm signguNm      libraryNm  openingYear
# 1     경상남도      창원시  경상남도교육청 마산도서관         1954
