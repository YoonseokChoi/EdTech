# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np

from google_play_scraper import reviews, Sort

import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

from konlpy.tag import Okt
from collections import Counter

from pprint import pprint
from PIL import Image

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 데이터 수집

# %% [markdown]
# ## 구글 playstore 리뷰 데이터

# %%
def gstore_reviews(app_id):
    # 리뷰 가져오기
    result = reviews(
        app_id,
        lang='ko',  # 한국어 리뷰
        country='kr',  # 한국
        sort=Sort.NEWEST,  # 최신 리뷰 먼저 가져오기
        count=100000  # 가져올 리뷰 수 (최대 100000)
    )

    # 리뷰 데이터
    review_data = result[0]

    # DataFrame으로 변환
    return pd.DataFrame(review_data)

# %% [markdown]
# ### 코딩밸리

# %%
cdv_df = gstore_reviews("inc.ulift.cv")

# %%
print(cdv_df.shape)
cdv_df.head(2)
# Out:
# (72, 11)
#                                reviewId userName  \
# 0  01b519dd-55d5-459e-9e39-8c3ec2be2573      이상헌
# 1  fa6bd9f2-f89f-4e2a-862f-1e2577daf5df      권유진
#
#                                            userImage              content  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...  파이썬을 아주 재미있게 학습중이에용
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...   강의 내용이 이해가 쏙쏙 됩니다.
#
#    score  thumbsUpCount reviewCreatedVersion                  at  \
# 0      5              0               2.11.6 2025-01-15 13:19:24
# 1      5              0               2.11.4 2025-01-04 22:37:52
#
#                                         replyContent           repliedAt  \
# 0  안녕하세요 회원님, 코딩밸리입니다.\n\n코딩밸리를 통해 재밌게 학습을 하고 계시다... 2025-01-17 09:46:02
# 1  안녕하세요 회원님, 코딩밸리입니다.\n앞으로도 저희 코딩밸리 강의에 만족하실 수 있... 2025-01-06 11:42:16
#
#   appVersion
# 0     2.11.6
# 1     2.11.4

# %% [markdown]
# ### Duolingo

# %%
# duo_df = gstore_reviews("com.duolingo")

# %%
# print(duo_df.shape)
# duo_df.head(2)

# %% [markdown]
# ### 뉴닉

# %%
nn_df = gstore_reviews("com.newneek.newneekapp")

# %%
print(nn_df.shape)
nn_df.head(2)
# Out:
# (331, 11)
#                                reviewId userName  \
# 0  831ddfd4-5921-442f-9d10-1c4e752de825    부북당기당
# 1  d28a9387-a479-4583-8dc3-b01f2049b3d7     xv f
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0                            정치적 중립을 지켜라. 민주당에 돈 받았냐      1              0
# 1  예전이랑 너무 많이 달라진 것 같네요 특히 1분 정도씩으로 요약해서 하루에 여러 기...      2              2
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                0.7.0 2025-01-17 09:24:59         None       NaT      0.7.0
# 1                0.7.0 2025-01-05 18:47:37         None       NaT      0.7.0

# %% [markdown]
# ### 솔로런

# %%
slr_df = gstore_reviews("com.sololearn")

# %%
print(slr_df.shape)
slr_df.head(2)
# Out:
# (806, 11)
#                                reviewId userName  \
# 0  7c7ca4bb-d924-4559-b60a-ac413781363c  거북이와두루미
# 1  15a801d9-e08d-4da9-9300-26bf20b11ef7  Max Lee
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0                              글씨가 작다. 너무. 다른 어플로 간다      1              0
# 1  Unable to type in correct answers in javascrip...      1              0
#
#   reviewCreatedVersion                  at  \
# 0               4.87.0 2024-10-07 13:24:04
# 1               4.75.1 2024-05-31 21:50:16
#
#                                         replyContent           repliedAt  \
# 0  Hey, Thanks for your feedback. We work tireles... 2024-10-13 23:09:26
# 1  Hello,\nWe are sorry for the caused inconvenie... 2024-06-04 22:41:26
#
#   appVersion
# 0     4.87.0
# 1     4.75.1

# %% [markdown]
# ### MIMO

# %%
mimo_df = gstore_reviews('com.getmimo')
print(mimo_df.shape)
mimo_df.head()
# Out:
# (287, 11)
#                                reviewId       userName  \
# 0  ec58f532-51f0-4910-bb8e-2f1dc0218f85           치즈케익
# 1  868ee219-fe63-46e0-9d05-a67ac82318bf            최유진
# 2  a8982457-8a77-4a8e-960a-bd5b25ea34ba  김건호 (GeonKim)
# 3  94d0e1eb-20fe-4522-9627-a8befa2c7705            김민규
# 4  a5c79fa0-4451-4510-b0de-bca454c788a2           TT F
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0                                코딩에 대한 기본지식을 잘 알려줘요      5              0
# 1                                               good      5              0
# 2  world's best! i would like to learn go lang on...      5              0
# 3  일단 프로버전을 결제해도 PC에서 프로젝트 같은 것들을 해보려면 또 MAX로 전환해...      3              0
# 4                                               good      5              0
#
#   reviewCreatedVersion                  at  \
# 0                 5.13 2025-01-19 23:21:25
# 1                 5.13 2025-01-11 14:52:22
# 2                 5.13 2025-01-08 08:29:27
# 3                 5.13 2025-01-05 23:55:48
# 4                 5.13 2025-01-05 17:53:42
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3  We apologize for any confusion. The Pro versio... 2025-01-13 23:01:52
# 4                                               None                 NaT
#
#   appVersion
# 0       5.13
# 1       5.13
# 2       5.13
# 3       5.13
# 4       5.13

# %% [markdown]
# # 데이터 분석

# %%
from konlpy.tag import Okt
from wordcloud import WordCloud
from stopwords import get_stopwords
from collections import Counter

def get_WordCloud(df, title):
    okt = Okt()

    # 한국어 불용어
    korean_stopwords = set(get_stopwords(language='korean'))
    custom_stopwords = {
        '이', '그', '저', '것', '나', '너', '우리', '저희', '그들', '그녀', 
        '입니다', '하', '이것', '저것', '다', '되다', '하다', '있다', '없다', 
        '과', '도', '의', '는', '은', '를', '이', '가', '에서', '에', '을',
        '아주','진짜','정말','가장','너무','정말로','대해','대하여','이건','모든','저건','통해',
        '제발','자꾸','계속','이후','부분','완전','그냥','걍','이면','때문','내지','해도','달이'
    }
    total_stopwords = korean_stopwords.union(custom_stopwords)
    
    
    combined_text = ' '.join(df['content'].astype(str))
    
    tokens_ko = okt.nouns(combined_text)
    
    filtered_tokens = [word for word in tokens_ko if word not in total_stopwords and len(word) > 1]

    word_freq = Counter(filtered_tokens)
    
    top_words = word_freq.most_common(80)
#     print("상위 50개 단어:", top_100_words)  # 상위 50개 단어 출력
    bubble_mask = np.array(Image.open('./img/YoonseokChoi.jpg'))
    wordcloud = WordCloud(
        font_path="C://Windows/Fonts/malgun.ttf",  # Windows 한글 폰트 경로
        width=300,
        height=150,
        background_color='black',  # 배경색
        colormap='Pastel1',  # 색상 맵 (색상 팔레트)
#         max_font_size=200,  # 최대 폰트 크기
#         min_font_size=10,  # 최소 폰트 크기
        max_words=80,  # 최대 단어 수
#         contour_color='black',  # 단어 클라우드 외곽선 색상
#         contour_width=1,  # 외곽선 두께
#         random_state=42,  # 결과 일관성 유지
        mask = bubble_mask

    ).generate_from_frequencies(dict(top_words))
    
    # 워드 클라우드 출력
    plt.figure(figsize=(10,10))
    plt.title(title, fontsize=18, fontweight='bold', loc = 'left')
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off') 
    plt.show()

# %% [markdown]
# ## 코딩밸리

# %% [markdown]
# ### Word Cloud

# %%
df1 = cdv_df.loc[cdv_df['score']<=2]
get_WordCloud(df1, "<코딩밸리> User Reviews")

# %%
get_WordCloud(cdv_df, "<코딩밸리> PlayStore Reviews")

# %% [markdown]
# ## Duolingo

# %% [markdown]
# ### Word Cloud

# %%
# get_WordCloud(duo_df, "<듀오링고> PlayStore 리뷰")

# %% [markdown]
# ## 뉴닉

# %% [markdown]
# ### Word Cloud

# %%
df1 = nn_df.loc[nn_df['score']<=2]
get_WordCloud(df1, "<뉴닉> PlayStore Reviews")

# %%
get_WordCloud(nn_df, '<뉴닉> PlayStore Reviews')

# %% [markdown]
# ## 솔로런

# %% [markdown]
# ### WordCloud

# %%
df1 = slr_df.loc[slr_df['score']<=3]
get_WordCloud(df1, "<SoloLearn> PlayStore Reviews")

# %%
get_WordCloud(slr_df, "<SoloLearn> PlayStore Reviews")

# %% [markdown]
# ## MIMO

# %% [markdown]
# ### Word Cloud

# %%
df1 = mimo_df.loc[mimo_df['score']<=3]
get_WordCloud(df1, "<Mimo> PlayStore Reviews")

# %%
get_WordCloud(mimo_df, "<Mimo> PlayStore Reviews")
