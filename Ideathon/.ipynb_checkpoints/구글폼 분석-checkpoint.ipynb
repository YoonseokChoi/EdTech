# %%
import pandas as pd
import numpy as np

from google_play_scraper import reviews, Sort

import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

from konlpy.tag import Okt
from collections import Counter

from pprint import pprint

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data

# %% [markdown]
# ## 전처리

# %%
df = pd.read_csv('./data/아이디어톤 설문지.csv')

df.columns = [
    "timestamp",                # 타임스탬프
    "gender",                   # 성별
    "age",                      # 연령
    "experience",               # 경력
    "company_type",             # 재직 중인 기업의 형태를 선택해 주세요.
    "is_IT",           # IT 기술 업계 종사자인가요?
    "is_dev",               # 직업
    "roles1",            # 현재 담당하고 계신 직무를 선택해주세요. (중복 선택 가능)
    "issues_with_non_dev",      # 비개발 직군과 협업 시 주로 겪는 어려움을 선택해주세요. (중복 선택 가능)
    "issues_with_dev1",          # 개발 직군 간 협업 시 주로 겪는 어려움을 선택해주세요. (중복 선택 가능)
    "com_feedback1",   # 협업과 소통 개선을 위한 의견을 자유롭게 작성해 주세요.
    "use_service1",       # 타 개발 직군과의 원활한 소통을 위해 [하루 5분 IT 학습 서비스] 를 제공한다면 사용할 의향이 있으십니까?
    "reason1",        # 해당 답변을 선택하신 이유는 무엇인가요?
    "roles2",           # 현재 담당하고 계신 직무를 선택해주세요. (중복 선택 가능)
    "issues_with_dev2",    # 개발자와의 소통/협업 시 주로 겪는 어려움을 선택해주세요. (중복 선택 가능)
    "com_feedback2",      # 협업과 소통 개선을 위한 의견을 자유롭게 작성해 주세요.
    "use_service2",     # 개발자와의 원활한 소통을 위해 [하루 5분 IT 학습 서비스] 를 제공한다면 사용할 의향이 있으십니까?
    "reason2"   # 해당 답변을 선택하신 이유는 무엇인가요?
]

df.drop(columns='timestamp', inplace=True)

print(df.shape)
df.head(2)
# Out:
# (49, 17)
#   gender  age experience company_type is_IT               is_dev  \
# 0     남성  20대      1년 미만         스타트업     예  개발자 (데이터·인프라 직군 포함)
# 1     남성  20대      1년~3년         중소기업     예  개발자 (데이터·인프라 직군 포함)
#
#                        roles1  \
# 0  Back-end 개발자;Front-end 개발자
# 1                Back-end 개발자
#
#                                  issues_with_non_dev  \
# 0                         개발 업무에 대한 이해 부족으로 소통이 어렵다.
# 1  개발 업무에 대한 이해 부족으로 소통이 어렵다.;기술적 용어를 설명하는 데 어려움을...
#
#                              issues_with_dev1  \
# 0                      기술적 용어 차이로 인해 소통이 어렵다.
# 1  업무 우선순위가 달라 갈등이 생긴다.;타 개발환경에 대한 이해도가 부족하다.
#
#                                      com_feedback1 use_service1  \
# 0                                              NaN            예
# 1  협업을 위해선 서로 개발 비개발 직군에 대한 이해도를 높이도록 이해해가며 노력해나가기            예
#
#                                              reason1 roles2 issues_with_dev2  \
# 0                                            도움될거같아서    NaN              NaN
# 1  타 개발 직군이 어떤 용어를 주로 사용하고, 환경을 어떻게 구성해가는지 이해할 수 ...    NaN              NaN
#
#   com_feedback2 use_service2 reason2
# 0           NaN          NaN     NaN
# 1           NaN          NaN     NaN

# %%
dev_df = df.loc[df['is_dev']!='비개발자']
dev_df.drop(
    columns = ['roles2', 'issues_with_dev2', 'com_feedback2', 'use_service2', 'reason2'],
    inplace = True
)

dev_df.columns = [
    'gender','age','experience','company_type','is_IT','is_dev',
    'roles','issues_with_non_dev','issues_with_dev','com_feedback','use_service','reason'
]

print(dev_df.shape)
dev_df.head(2)
# Out:
# (37, 12)
#   gender  age experience company_type is_IT               is_dev  \
# 0     남성  20대      1년 미만         스타트업     예  개발자 (데이터·인프라 직군 포함)
# 1     남성  20대      1년~3년         중소기업     예  개발자 (데이터·인프라 직군 포함)
#
#                         roles  \
# 0  Back-end 개발자;Front-end 개발자
# 1                Back-end 개발자
#
#                                  issues_with_non_dev  \
# 0                         개발 업무에 대한 이해 부족으로 소통이 어렵다.
# 1  개발 업무에 대한 이해 부족으로 소통이 어렵다.;기술적 용어를 설명하는 데 어려움을...
#
#                               issues_with_dev  \
# 0                      기술적 용어 차이로 인해 소통이 어렵다.
# 1  업무 우선순위가 달라 갈등이 생긴다.;타 개발환경에 대한 이해도가 부족하다.
#
#                                       com_feedback use_service  \
# 0                                              NaN           예
# 1  협업을 위해선 서로 개발 비개발 직군에 대한 이해도를 높이도록 이해해가며 노력해나가기           예
#
#                                               reason
# 0                                            도움될거같아서
# 1  타 개발 직군이 어떤 용어를 주로 사용하고, 환경을 어떻게 구성해가는지 이해할 수 ...

# %%
non_dev_df = df.loc[df['is_dev']=='비개발자']
non_dev_df.drop(
    columns = ['roles1', 'issues_with_dev1', 'com_feedback1', 'use_service1','reason1'],
    inplace = True
)

cols = ['gender','age','experience','company_type','is_IT','is_dev',
        'roles2','issues_with_non_dev','issues_with_dev2','com_feedback2','use_service2','reason2']
non_dev_df = non_dev_df[cols]

non_dev_df.columns = [
    'gender','age','experience','company_type','is_IT','is_dev',
    'roles','issues_with_non_dev','issues_with_dev','com_feedback','use_service','reason'
]

print(non_dev_df.shape)
non_dev_df.head(2)
# Out:
# (12, 12)
#   gender  age experience company_type is_IT is_dev roles issues_with_non_dev  \
# 6     남성  30대      1년 미만         중소기업   아니오   비개발자   기획자                 NaN
# 7     여성  40대      5년 이상         프리랜서     예   비개발자   기획자                 NaN
#
#                                  issues_with_dev  \
# 6                                   어려움을 겪지 않는다.
# 7  기술적 문제 해결 시 의견 충돌이 발생한다.;업무 우선순위가 달라 갈등이 생긴다.
#
#                              com_feedback use_service  \
# 6                                     NaN         아니오
# 7  기획자나 개발자나 프로덕트 or 프로세스 전체를 보는 눈이 필요함.          아니오
#
#                                               reason
# 6                                                 ⁶ㅛ
# 7  학습 내용이 뭔지 모르겠지만 저는 학습할 필요는 없는 수준임. \n그리고 학습을 하...

# %%
display(dev_df.head(1))
display(non_dev_df.head(1))
# Out:
#   gender  age experience company_type is_IT               is_dev  \
# 0     남성  20대      1년 미만         스타트업     예  개발자 (데이터·인프라 직군 포함)
#
#                        roles1         issues_with_non_dev  \
# 0  Back-end 개발자;Front-end 개발자  개발 업무에 대한 이해 부족으로 소통이 어렵다.
#
#          issues_with_dev1 com_feedback1 use_service1  reason1
# 0  기술적 용어 차이로 인해 소통이 어렵다.           NaN            예  도움될거같아서
#   gender  age experience company_type is_IT is_dev roles2 issues_with_non_dev  \
# 6     남성  30대      1년 미만         중소기업   아니오   비개발자    기획자                 NaN
#
#   issues_with_dev2 com_feedback2 use_service2 reason2
# 6     어려움을 겪지 않는다.           NaN          아니오      ⁶ㅛ

# %%
df = pd.concat([dev_df, non_dev_df])
df = df.reset_index(drop=True)

print(df.shape)
df.head()
# Out:
# (49, 12)
#   gender  age experience company_type is_IT               is_dev  \
# 0     남성  20대      1년 미만         스타트업     예  개발자 (데이터·인프라 직군 포함)
# 1     남성  20대      1년~3년         중소기업     예  개발자 (데이터·인프라 직군 포함)
# 2     남성  20대      1년~3년          대기업   아니오  개발자 (데이터·인프라 직군 포함)
# 3     남성  30대      1년~3년         스타트업     예  개발자 (데이터·인프라 직군 포함)
# 4     여성  20대      1년~3년         중소기업   아니오  개발자 (데이터·인프라 직군 포함)
#
#                         roles  \
# 0  Back-end 개발자;Front-end 개발자
# 1                Back-end 개발자
# 2                    시스템 엔지니어
# 3  Back-end 개발자;Front-end 개발자
# 4               Front-end 개발자
#
#                                  issues_with_non_dev  \
# 0                         개발 업무에 대한 이해 부족으로 소통이 어렵다.
# 1  개발 업무에 대한 이해 부족으로 소통이 어렵다.;기술적 용어를 설명하는 데 어려움을...
# 2                              요구사항이 불명확하여 업무가 지연된다.
# 3     기술적 용어를 설명하는 데 어려움을 겪는다.;요구사항이 불명확하여 업무가 지연된다.
# 4   개발 업무에 대한 이해 부족으로 소통이 어렵다.;요구사항이 불명확하여 업무가 지연된다.
#
#                                 issues_with_dev  \
# 0                        기술적 용어 차이로 인해 소통이 어렵다.
# 1    업무 우선순위가 달라 갈등이 생긴다.;타 개발환경에 대한 이해도가 부족하다.
# 2   기술적 용어 차이로 인해 소통이 어렵다.;업무 우선순위가 달라 갈등이 생긴다.
# 3  기술적 용어 차이로 인해 소통이 어렵다.;타 개발환경에 대한 이해도가 부족하다.
# 4                         타 개발환경에 대한 이해도가 부족하다.
#
#                                         com_feedback use_service  \
# 0                                                NaN           예
# 1    협업을 위해선 서로 개발 비개발 직군에 대한 이해도를 높이도록 이해해가며 노력해나가기           예
# 2  듣는 사람의 수준을 고려한 의견 전달이 필요하고, 협업을 위해 타분야에 대한 이해도...           예
# 3  용어를 사용할 때 서로가 이해할 수 있는 정확한 용어를 사용하면 소통간 오해가 줄어...           예
# 4      비개발직군 분들이 개발 업무에 대한 이해도를 높이고 업무를 전달해줬으면 좋겠습니다           예
#
#                                               reason
# 0                                            도움될거같아서
# 1  타 개발 직군이 어떤 용어를 주로 사용하고, 환경을 어떻게 구성해가는지 이해할 수 ...
# 2  소프트웨어 분야의 트렌드를 익히고 배경 지식을 쌓아두는 역량은 모든 산업 분야에서 ...
# 3  특히 비 개발 직군과 대화를 할 때 이해를 돕기 위한 적절한 단어 / 비유를 찾는 ...
# 4  백이나 통합인프라 부분이랑 협업할 일은 많은데, 그쪽에 대한 용어 지식은 별로 없습...

# %%
df = pd.read_csv("./data/form.csv", index_col=False)
print(df.shape)
df.sample(3)
# Out:
# (49, 19)
#     Unnamed: 0                     timestamp gender  age experience  \
# 14          14   2025/01/10 6:22:00 오후 GMT+9     남성  20대      1년~3년
# 33          33   2025/01/12 4:59:38 오후 GMT+9     남성  20대      1년 미만
# 23          23  2025/01/10 10:29:02 오후 GMT+9     여성  20대      1년 미만
#
#    company_type is_it_industry           occupation current_roles  \
# 14          대기업              예  개발자 (데이터·인프라 직군 포함)  Back-end 개발자
# 33         스타트업              예                 비개발자           NaN
# 23         중소기업              예  개발자 (데이터·인프라 직군 포함)      데이터 엔지니어
#
#                                   issues_with_non_dev  \
# 14  개발 업무에 대한 이해 부족으로 소통이 어렵다.;기술적 용어를 설명하는 데 어려움을...
# 33                                                NaN
# 23     기술적 용어를 설명하는 데 어려움을 겪는다.;요구사항이 불명확하여 업무가 지연된다.
#
#                                    issues_with_dev collaboration_feedback  \
# 14                                    어려움을 겪지 않는다.                    NaN
# 33                                             NaN                    NaN
# 23  기술적 문제 해결 시 의견 충돌이 발생한다.;타 개발환경에 대한 이해도가 부족하다.                    NaN
#
#    use_service_intent                                  reason_for_intent  \
# 14                  예                               결국 일은 같이 해야 하기 때문입니다
# 33                NaN                                                NaN
# 23                  예  타 개발 직군의 용어나 지식을 배우면서 업무에 대한 이해를 높여 협업 스킬을 올리는...
#
#                 selected_roles                          issues_with_dev_comms  \
# 14                         NaN                                            NaN
# 33  프로젝트 매니저 (Project Manager)  기술적 문제 해결 시 의견 충돌이 발생한다.;업무 우선순위가 달라 갈등이 생긴다.
# 23                         NaN                                            NaN
#
#                                   collaboration_ideas service_usage_intent  \
# 14                                                NaN                  NaN
# 33  개발자와 비개발자 모두 기술에 대한 이해가 필요하고 비개발자도 어느 정도는 직접 해...                    예
# 23                                                NaN                  NaN
#
#                        reason_for_usage_intent
# 14                                         NaN
# 33  하루에 5분으로 저런 유용한 지식을 얻을 수 있다면 매우 좋을 것 같습니다.
# 23                                         NaN

# %% [markdown]
# # 분석

# %% [markdown]
# ## 서비스 사용 희망 여부

# %% [markdown]
# ### 직무별

# %%
df1 = df.assign(current_roles=df["current_roles"].str.split(";")).explode("current_roles")
df1 = round(df1.groupby('current_roles')['use_service_intent'].value_counts(normalize=True).reset_index(),2)
df1 = df1.sort_values(by = ['current_roles','use_service_intent'])
df1
# Out:
#     current_roles use_service_intent  proportion
# 1         AI 엔지니어                아니오        0.40
# 0         AI 엔지니어                  예        0.60
# 3    Back-end 개발자                아니오        0.14
# 2    Back-end 개발자                  예        0.86
# 4     DevOps 엔지니어                아니오        0.67
# 5     DevOps 엔지니어                  예        0.33
# 7   Front-end 개발자                아니오        0.22
# 6   Front-end 개발자                  예        0.78
# 8      MLOps 엔지니어                아니오        0.67
# 9      MLOps 엔지니어                  예        0.33
# 10         게임 개발자                  예        1.00
# 12        데이터 분석가                아니오        0.50
# 11        데이터 분석가                  예        0.50
# 13     데이터 사이언티스트                  예        1.00
# 14       데이터 엔지니어                  예        1.00
# 16      소프트웨어 개발자                아니오        0.40
# 15      소프트웨어 개발자                  예        0.60
# 17       시스템 엔지니어                  예        1.00
# 18         웹 퍼블리셔                  예        1.00
# 20       인프라 엔지니어                아니오        0.33
# 19       인프라 엔지니어                  예        0.67
# 21       임베디드 개발자                  예        1.00
# 22      정보 보안 전문가                  예        1.00
# 23      클라우드 엔지니어                아니오        1.00

# %%
# fig, ax = plt.subplots(figsize=(10,5))
# _=sns.barplot(
#     data = df1,
#     x = 'current_roles', y = 'proportion',
#     hue = 'use_service_intent',
#     ax = ax
# )
# _=plt.xticks(rotation=45)

# %%
# expanded = (
#     df.assign(current_roles=df["current_roles"].str.split(";"))
#     .explode("current_roles")
# )

# # 직무별 use_service_intent 값 카운트
# result = expanded.groupby(["current_roles", "use_service_intent"]).size().unstack(fill_value=0)

# result['아니오 비율'] = round(result['아니오'] / (result['아니오'] + result['예']),2)
# result['예 비율'] = round(result['예'] / (result['아니오'] + result['예']),2)

# # 결과 확인
# result

# %% [markdown]
# ### 기업규모별

# %%
df1 = round(df.groupby(['company_type'])['use_service_intent'].value_counts(normalize=True).reset_index(),2)
df1.head()
# Out:
#   company_type use_service_intent  proportion
# 0          대기업                  예        0.73
# 1          대기업                아니오        0.27
# 2          대학원                  예        1.00
# 3         스타트업                  예        0.62
# 4         스타트업                아니오        0.38

# %%
fig, ax = plt.subplots(figsize=(10,5))
_=sns.barplot(
    data = df1,
    x = 'company_type', y = 'proportion',
    hue = 'use_service_intent',
    ax = ax
)
_=plt.xticks(rotation=45)

# %% [markdown]
# ### IT 기업 여부

# %%
round(df.groupby(['is_it_industry'])['use_service_intent'].value_counts(normalize=True).to_frame(),2)
# Out:
#                                    proportion
# is_it_industry use_service_intent
# 아니오            예                         0.80
#                아니오                       0.20
# 예              예                         0.72
#                아니오                       0.28

# %% [markdown]
# ### 성별

# %%
round(df.groupby(['gender'])['use_service_intent'].value_counts(normalize=True).to_frame(),2)
# Out:
#                            proportion
# gender use_service_intent
# 남성     예                         0.77
#        아니오                       0.23
# 여성     예                         0.67
#        아니오                       0.33

# %% [markdown]
# ### 연차별

# %%
round(df.groupby(['experience'])['use_service_intent'].value_counts(normalize=True).to_frame(), 2)
# Out:
#                                proportion
# experience use_service_intent
# 1년 미만      예                         0.87
#            아니오                       0.13
# 1년~3년      예                         0.65
#            아니오                       0.35
# 3년~5년      예                         0.67
#            아니오                       0.33
# 5년 이상      아니오                       0.50
#            예                         0.50
