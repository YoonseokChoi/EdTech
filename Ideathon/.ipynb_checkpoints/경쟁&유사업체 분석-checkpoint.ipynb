# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np

from google_play_scraper import reviews, Sort

import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

from konlpy.tag import Okt
from collections import Counter

from pprint import pprint

# %% [markdown]
# # 데이터 수집

# %% [markdown]
# ## 구글 playstore 리뷰 데이터

# %%
def gstore_reviews(app_id):
    # 리뷰 가져오기
    result = reviews(
        app_id,
        lang='ko',  # 한국어 리뷰
        country='kr',  # 한국
        sort=Sort.NEWEST,  # 최신 리뷰 먼저 가져오기
        count=100000  # 가져올 리뷰 수 (최대 100000)
    )

    # 리뷰 데이터
    review_data = result[0]

    # DataFrame으로 변환
    return pd.DataFrame(review_data)

# %% [markdown]
# ### 코딩밸리

# %%
cdv_df = gstore_reviews("inc.ulift.cv")

# %%
print(cdv_df.shape)
cdv_df.head(2)
# Out:
# (71, 11)
#                                reviewId userName  \
# 0  fa6bd9f2-f89f-4e2a-862f-1e2577daf5df      권유진
# 1  c4b09f59-4fc8-4bac-b1bd-40e4ae1ab084      노백현
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0                                 강의 내용이 이해가 쏙쏙 됩니다.      5              0
# 1  코딩입문으로는 이 앱이 정말 좋은거 같습니다. 다만 아쉬운 점이 있다면 파이썬이랑 ...      5              1
#
#   reviewCreatedVersion                  at  \
# 0               2.11.4 2025-01-04 22:37:52
# 1               2.11.0 2024-12-22 02:10:06
#
#                                         replyContent           repliedAt  \
# 0  안녕하세요 회원님, 코딩밸리입니다.\n앞으로도 저희 코딩밸리 강의에 만족하실 수 있... 2025-01-06 11:42:16
# 1  안녕하세요 회원님, 코딩밸리입니다.\n우선 귀한 시간 내어 소중한 의견 전달해주셔서... 2024-12-27 12:54:10
#
#   appVersion
# 0     2.11.4
# 1     2.11.0

# %% [markdown]
# ### Duolingo

# %%
duo_df = gstore_reviews("com.duolingo")

# %%
print(duo_df.shape)
duo_df.head(2)
# Out:
# (4500, 11)
#                                reviewId    userName  \
# 0  291762e4-d629-43d1-a653-5d1d33f154d7  Google 사용자
# 1  73035dcb-9edf-4b7a-b1d0-56080f597a7c  Google 사용자
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                             content  score  thumbsUpCount  \
# 0  너무 재밌고 공부도 잘 되는데 듀오링고 광고가 많이 나오는 것만 없으면 좋을 것 같아요      4              0
# 1               이건 재밌고 초등학생들도 하면 재밌게 플레이 할꺼예요 별5개:)      5              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0               6.11.4 2025-01-07 20:59:32         None      None     6.11.4
# 1               6.11.4 2025-01-07 20:59:02         None      None     6.11.4

# %% [markdown]
# ### 뉴닉

# %%
nn_df = gstore_reviews("com.newneek.newneekapp")

# %%
print(nn_df.shape)
nn_df.head(2)
# Out:
# (331, 11)
#                                reviewId      userName  \
# 0  d28a9387-a479-4583-8dc3-b01f2049b3d7          xv f
# 1  de2996c8-482d-410f-bf4e-b39815d3ff13  Seunghwa Cho
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  예전이랑 너무 많이 달라진 것 같네요 특히 1분 정도씩으로 요약해서 하루에 여러 기...      2              2
# 1                                      글에 알맹이가 별로 없음      3              1
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                0.7.0 2025-01-05 18:47:37         None       NaT      0.7.0
# 1                0.7.0 2025-01-04 23:22:42         None       NaT      0.7.0

# %% [markdown]
# ### 솔로런

# %%
slr_df = gstore_reviews("com.sololearn")

# %%
print(slr_df.shape)
slr_df.head(2)
# Out:
# (806, 11)
#                                reviewId userName  \
# 0  7c7ca4bb-d924-4559-b60a-ac413781363c  거북이와두루미
# 1  15a801d9-e08d-4da9-9300-26bf20b11ef7  Max Lee
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0                              글씨가 작다. 너무. 다른 어플로 간다      1              0
# 1  Unable to type in correct answers in javascrip...      1              0
#
#   reviewCreatedVersion                  at  \
# 0               4.87.0 2024-10-07 13:24:04
# 1               4.75.1 2024-05-31 21:50:16
#
#                                         replyContent           repliedAt  \
# 0  Hey, Thanks for your feedback. We work tireles... 2024-10-13 23:09:26
# 1  Hello,\nWe are sorry for the caused inconvenie... 2024-06-04 22:41:26
#
#   appVersion
# 0     4.87.0
# 1     4.75.1

# %% [markdown]
# ### MIMO

# %%
mimo_df = gstore_reviews('com.getmimo')
print(mimo_df.shape)
mimo_df.head()
# Out:
# (286, 11)
#                                reviewId       userName  \
# 0  868ee219-fe63-46e0-9d05-a67ac82318bf            최유진
# 1  a8982457-8a77-4a8e-960a-bd5b25ea34ba  김건호 (GeonKim)
# 2  94d0e1eb-20fe-4522-9627-a8befa2c7705            김민규
# 3  a5c79fa0-4451-4510-b0de-bca454c788a2           TT F
# 4  fe2d3268-1809-4553-9f9b-f0deafda2c1d            신주언
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0                                               good      5              0
# 1  world's best! i would like to learn go lang on...      5              0
# 2  일단 프로버전을 결제해도 PC에서 프로젝트 같은 것들을 해보려면 또 MAX로 전환해...      3              0
# 3                                               good      5              0
# 4                             다 좋은데 한국어 지원해 줬으면 합니다.      4              0
#
#   reviewCreatedVersion                  at  \
# 0                 5.13 2025-01-11 14:52:22
# 1                 5.13 2025-01-08 08:29:27
# 2                 5.13 2025-01-05 23:55:48
# 3                 5.13 2025-01-05 17:53:42
# 4                 5.13 2024-12-29 20:32:19
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2  We apologize for any confusion. The Pro versio... 2025-01-13 23:01:52
# 3                                               None                 NaT
# 4                                               None                 NaT
#
#   appVersion
# 0       5.13
# 1       5.13
# 2       5.13
# 3       5.13
# 4       5.13

# %% [markdown]
# # 데이터 분석

# %%
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def get_WordCloud(df):
    okt = Okt()

    # 명사, 동사만 추출하는 함수
    def extract_words(text):
        words = okt.pos(text)
        return ' '.join([word for word, tag in words if tag in ['Noun', 'Verb']])

    # 데이터 전처리 (명사, 동사 필터링)
    df['filtered_content'] = df['content'].apply(extract_words)
    
    # 단어 카운트 계산
    vectorizer = CountVectorizer(
        max_features=50,
        stop_words=['은', '는', '이', '가', '을', '를', '의', '에', '과', '도', '에서', '하다']
    )
    word_counts = vectorizer.fit_transform(df['filtered_content'])
    word_freq = dict(zip(vectorizer.get_feature_names_out(), word_counts.toarray().sum(axis=0)))
    
    # 워드클라우드 생성
    wordcloud = WordCloud(font_path="C:\\Windows\\Fonts\\malgun.ttf", width=800, height=400).generate_from_frequencies(word_freq)
    
    # 결과 출력
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
# # 워드 클라우드 생성을 위해 모든 문자열을 하나로 합치기
# combined_text = ' '.join(cdv_df['content'].astype(str))
# t = Okt()
# tokens_ko = t.nouns(combined_text) # 명사 분석
# b

# %%
pip install korean_stopwords
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement korean_stopwords (from versions: none)
# ERROR: No matching distribution found for korean_stopwords

# %%
import pandas as pd
from konlpy.tag import Okt
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from korean_stopwords import get_stopwords
from collections import Counter

# 한글 불용어 사전 다운로드 및 설정
# nltk.download('stopwords')
# nltk.download('punkt')

def get_WordCloud(df):
    # Okt 객체 생성 (형태소 분석기)
    okt = Okt()

    # 한국어 불용어 사전 (NLTK 영어 불용어 + 사용자 정의 불용어)
    korean_stopwords = set(get_stopwords())  # korean-stopwords 라이브러리 사용
    custom_stopwords = {'이', '그', '저', '것', '나', '너', '우리', '저희', '그들', '그녀', '입니다', '하', '이것', '저것', '다', '되다', '하다', '있다', '없다', '과', '도', '의', '는', '은', '를', '이', '가', '에서', '에', '을'}
    total_stopwords = korean_stopwords.union(custom_stopwords)
    
    # 모든 리뷰 내용을 하나로 결합
    combined_text = ' '.join(df['content'].astype(str))
    
    # 명사 추출 (형태소 분석)
    tokens_ko = okt.nouns(combined_text)
    
    # 불용어 제거
    filtered_tokens = [word for word in tokens_ko if word not in total_stopwords and len(word) > 1]

    # 단어 빈도 계산
    word_freq = Counter(filtered_tokens)
    print("상위 10개 단어:", word_freq.most_common(10))  # 상위 10개 단어 출력
    
    # 워드 클라우드 생성
    wordcloud = WordCloud(
        font_path="C:\\Windows\\Fonts\\malgun.ttf",  # Windows 한글 폰트 경로
        width=800,
        height=400,
        background_color='white'
    ).generate_from_frequencies(word_freq)
    
    # 워드 클라우드 출력
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 6
#       4 import matplotlib.pyplot as plt
#       5 from nltk.corpus import stopwords
# ----> 6 from korean_stopwords import get_stopwords
#       7 from collections import Counter
#       9 # 한글 불용어 사전 다운로드 및 설정
#      10 # nltk.download('stopwords')
#      11 # nltk.download('punkt')
#
# ModuleNotFoundError: No module named 'korean_stopwords'

# %% [markdown]
# ## 코딩밸리

# %% [markdown]
# ### Word Cloud

# %%
get_WordCloud(cdv_df)

# %%
# # 한글 불용어 사전 다운로드 (필요시 실행)
# nltk.download('stopwords')
# nltk.download('punkt')

# %% [markdown]
# ## Duolingo

# %% [markdown]
# ### Word Cloud

# %%
get_WordCloud(duo_df)
# Out:
# KeyboardInterrupt

# %%
perform_text_mining(duo_df)
# Out:
# 총 토큰 수: 25811
# 고유 토큰 수: 3057
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 perform_text_mining(duo_df)
#
# Cell In[28], line 26, in perform_text_mining(df)
#      23 print(f"고유 토큰 수: {len(set(tokens_ko))}")
#      25 # 한국어 불용어 추가
# ---> 26 korean_stopwords = set(stopwords.words('korean'))  # NLTK 한글 불용어
#      27 custom_stopwords = {'이', '있다', '하다', '것', '수', '되다', '그'}  # 추가 사용자 지정
#      28 total_stopwords = korean_stopwords.union(custom_stopwords)
#
# File ~\anaconda3\Lib\site-packages\nltk\corpus\reader\wordlist.py:21, in WordListCorpusReader.words(self, fileids, ignore_lines_startswith)
#      18 def words(self, fileids=None, ignore_lines_startswith="\n"):
#      19     return [
#      20         line
# ---> 21         for line in line_tokenize(self.raw(fileids))
#      22         if not line.startswith(ignore_lines_startswith)
#      23     ]
#
# File ~\anaconda3\Lib\site-packages\nltk\corpus\reader\api.py:218, in CorpusReader.raw(self, fileids)
#     216 contents = []
#     217 for f in fileids:
# --> 218     with self.open(f) as fp:
#     219         contents.append(fp.read())
#     220 return concat(contents)
#
# File ~\anaconda3\Lib\site-packages\nltk\corpus\reader\api.py:231, in CorpusReader.open(self, file)
#     223 """
#     224 Return an open stream that can be used to read the given file.
#     225 If the file's encoding is not None, then the stream will
#    (...)
#     228 :param file: The file identifier of the file to read.
#     229 """
#     230 encoding = self.encoding(file)
# --> 231 stream = self._root.join(file).open(encoding)
#     232 return stream
#
# File ~\anaconda3\Lib\site-packages\nltk\data.py:334, in FileSystemPathPointer.join(self, fileid)
#     332 def join(self, fileid):
#     333     _path = os.path.join(self._path, fileid)
# --> 334     return FileSystemPathPointer(_path)
#
# File ~\anaconda3\Lib\site-packages\nltk\compat.py:41, in py3_data.<locals>._decorator(*args, **kwargs)
#      39 def _decorator(*args, **kwargs):
#      40     args = (args[0], add_py3_data(args[1])) + args[2:]
# ---> 41     return init_func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\nltk\data.py:312, in FileSystemPathPointer.__init__(self, _path)
#     310 _path = os.path.abspath(_path)
#     311 if not os.path.exists(_path):
# --> 312     raise OSError("No such file or directory: %r" % _path)
#     313 self._path = _path
#
# OSError: No such file or directory: 'C:\\Users\\yoons\\AppData\\Roaming\\nltk_data\\corpora\\stopwords\\korean'

# %% [markdown]
# ## 뉴닉

# %% [markdown]
# ### Word Cloud

# %%
get_WordCloud(nn_df)

# %% [markdown]
# ## 솔로런

# %% [markdown]
# ### WordCloud

# %%
get_WordCloud(slr_df)

# %% [markdown]
# ## MIMO

# %% [markdown]
# ### Word Cloud

# %%
get_WordCloud(mimo_df)
